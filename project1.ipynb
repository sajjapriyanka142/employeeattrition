# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("EmployeeAttrition.csv")

# %%
dataset.head()
# Out:
#        Education JobInvolvement  JobLevel  DailyRate(USD)  MonthlyIncome(USD)  \
# 0        College           High         2            1102                5993
# 1  Below College         Medium         2             279                5130
# 2        College         Medium         1            1373                2090
# 3         Master           High         1            1392                2909
# 4  Below College           High         1             591                3468
#
#    NoofCompaniesWorked  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 0                    8                  8               6                   4
# 1                    1                 10              10                   7
# 2                    6                  7               0                   0
# 3                    1                  8               8                   7
# 4                    9                  6               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrentManager  TrainingTimesLastYear  \
# 0                        0                        5                      0
# 1                        1                        7                      3
# 2                        0                        0                      3
# 3                        3                        0                      3
# 4                        2                        2                      3
#
#   PerformanceRating Attrition(Yes/No)
# 0         Excellent               Yes
# 1       Outstanding                No
# 2         Excellent               Yes
# 3         Excellent                No
# 4         Excellent                No

# %%
dataset
# Out:
#           Education JobInvolvement  JobLevel  DailyRate(USD)  \
# 0           College           High         2            1102
# 1     Below College         Medium         2             279
# 2           College         Medium         1            1373
# 3            Master           High         1            1392
# 4     Below College           High         1             591
# 5           College           High         1            1005
# 6          Bachelor      Very High         1            1324
# 7     Below College           High         1            1358
# 8          Bachelor         Medium         3             216
# 9          Bachelor           High         2            1299
# 10         Bachelor      Very High         1             809
# 11          College         Medium         2             153
# 12    Below College           High         1             670
# 13          College           High         1            1346
# 14         Bachelor         Medium         1             103
# 15           Master      Very High         3            1389
# 16          College      Very High         1             334
# 17          College      Very High         1            1123
# 18           Master         Medium         4            1219
# 19         Bachelor           High         1             371
# 20          College      Very High         2             673
# 21           Master         Medium         1            1218
# 22           Master           High         3             419
# 23          College           High         1             391
# 24    Below College           High         1             699
# 25         Bachelor           High         5            1282
# 26    Below College            Low         1            1125
# 27           Master           High         2             691
# 28           Master         Medium         3             477
# 29           Master           High         5             705
# ...             ...            ...       ...             ...
# 1440        College           High         2             688
# 1441         Master           High         2             667
# 1442         Master           High         1            1092
# 1443       Bachelor           High         5             300
# 1444        College           High         1             310
# 1445         Master         Medium         4             582
# 1446       Bachelor         Medium         2             704
# 1447         Master            Low         2             301
# 1448       Bachelor         Medium         2             930
# 1449       Bachelor           High         1             529
# 1450         Master           High         3            1146
# 1451        College           High         2             345
# 1452         Master           High         2             878
# 1453         Master         Medium         2            1120
# 1454       Bachelor           High         2             374
# 1455         Master         Medium         1            1322
# 1456         Master           High         2            1199
# 1457         Master           High         1            1194
# 1458         Master            Low         1             287
# 1459        College         Medium         2            1378
# 1460         Master         Medium         1             468
# 1461       Bachelor         Medium         3             410
# 1462  Below College         Medium         4             722
# 1463       Bachelor           High         2             325
# 1464       Bachelor         Medium         1            1167
# 1465        College      Very High         2             884
# 1466  Below College         Medium         3             613
# 1467       Bachelor      Very High         2             155
# 1468       Bachelor         Medium         2            1023
# 1469       Bachelor      Very High         2             628
#
#       MonthlyIncome(USD)  NoofCompaniesWorked  TotalWorkingYears  \
# 0                   5993                    8                  8
# 1                   5130                    1                 10
# 2                   2090                    6                  7
# 3                   2909                    1                  8
# 4                   3468                    9                  6
# 5                   3068                    0                  8
# 6                   2670                    4                 12
# 7                   2693                    1                  1
# 8                   9526                    0                 10
# 9                   5237                    6                 17
# 10                  2426                    0                  6
# 11                  4193                    0                 10
# 12                  2911                    1                  5
# 13                  2661                    0                  3
# 14                  2028                    5                  6
# 25                          8                      3         Excellent
# 26                          7                      5       Outstanding
# 27                          2                      2         Excellent
# 28                         17                      4         Excellent
# 29                          1                      2         Excellent
# ...                       ...                    ...               ...
# 1440                        2                      3         Excellent
# 1441                        9                      2       Outstanding
# 1442                        2                      3         Excellent
# 1443                       14                      2         Excellent
# 1444                        8                      4         Excellent
# 1445                       10                      3       Outstanding
# 1446                        7                      2       Outstanding
# 1447                       11                      4       Outstanding
# 1448                        4                      5         Excellent
# 1449                        2                      4         Excellent
# 1450                        7                      2         Excellent
# 1451                        9                      1         Excellent
# 1452                        1                      3         Excellent
# 1453                        0                      2         Excellent
# 1454                        1                      3         Excellent
# 1455                        2                      2         Excellent
# 1456                        2                      2         Excellent
# 1457                        2                      2         Excellent
# 1458                        1                      5         Excellent
# 1459                        3                      2         Excellent
# 1460                        4                      3         Excellent
# 1461                        0                      3         Excellent
# 1462                        6                      2         Excellent
# 1463                        7                      2         Excellent
# 1464                        0                      2         Excellent
# 1465                        3                      3         Excellent
# 1466                        7                      5         Excellent
# 1467                        3                      0       Outstanding
# 1468                        8                      3         Excellent
# 1469                        2                      3         Excellent
#
#      Attrition(Yes/No)
# 0                  Yes
# 1                   No
# 2                  Yes
# 3                   No
# 4                   No
# 5                   No
# 6                   No
# 7                   No
# 8                   No
# 9                   No
# 10                  No
# 11                  No
# 12                  No
# 13                  No
# 14                 Yes
# 15                  No
# 16                  No
# 17                  No
# 18                  No
# 19                  No
# 20                  No
# 21                 Yes
# 22                  No
# 23                  No
# 24                 Yes
# 25                  No
# 26                 Yes
# 27                  No
# 28                  No
# 29                  No
# ...                ...
# 1440                No
# 1441                No
# 1442               Yes
# 1443                No
# 1444               Yes
# 1445                No
# 1446                No
# 1447                No
# 1448                No
# 1449                No
# 1450                No
# 1451                No
# 1452               Yes
# 1453                No
# 1454                No
# 1455                No
# 1456                No
# 1457                No
# 1458                No
# 1459                No
# 1460                No
# 1461               Yes
# 1462                No
# 1463                No
# 1464                No
# 1465                No
# 1466                No
# 1467                No
# 1468                No
# 1469                No
#
# [1470 rows x 14 columns]

# %%
y=dataset.iloc[:,13].values

# %%
y
# Out:
# array(['Yes', 'No', 'Yes', ..., 'No', 'No', 'No'], dtype=object)

# %%
x=dataset.iloc[:,:13].values

# %%
x
# Out:
# array([['College', 'High', 2, ..., 5, 0, 'Excellent'],
#        ['Below College', 'Medium', 2, ..., 7, 3, 'Outstanding'],
#        ['College', 'Medium', 1, ..., 0, 3, 'Excellent'],
#        ...,
#        ['Bachelor', 'Very High', 2, ..., 3, 0, 'Outstanding'],
#        ['Bachelor', 'Medium', 2, ..., 8, 3, 'Excellent'],
#        ['Bachelor', 'Very High', 2, ..., 2, 3, 'Excellent']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x[:,0]=lb.fit_transform(x[:,0])
lb1=LabelEncoder()
x[:,1]=lb1.fit_transform(x[:,1])
lb2=LabelEncoder()
x[:,12]=lb2.fit_transform(x[:,12])

# %%
lb3=LabelEncoder()
y[:,0]=lb3.fit_transform(y[:,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-268512e4e8c0> in <module>
#       1 lb3=LabelEncoder()
# ----> 2 y[:,0]=lb3.fit_transform(y[:,0]).values
#
# IndexError: too many indices for array

# %%
y
# Out:
# array(['Yes', 'No', 'Yes', ..., 'No', 'No', 'No'], dtype=object)

# %%
y=y.astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e1a09d7acfd2> in <module>
# ----> 1 y=y.astype('int')
#
# ValueError: invalid literal for int() with base 10: 'Yes'

# %%
x
# Out:
# array([[2, 0, 2, ..., 5, 0, 0],
#        [1, 2, 2, ..., 7, 3, 1],
#        [2, 2, 1, ..., 0, 3, 0],
#        ...,
#        [0, 3, 2, ..., 3, 0, 1],
#        [0, 2, 2, ..., 8, 3, 0],
#        [0, 3, 2, ..., 2, 3, 0]], dtype=object)

# %%
  from sklearn.preprocessing import OneHotEncoder
oh=OneHotEncoder(categorical_features=[0])
x=oh.fit_transform(x).toarray()
x=x[:,1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
oh1=OneHotEncoder(categorical_features=[3])
x=oh1.fit_transform(x).toarray()
x=x[:,1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x.shape
# Out:
# (1470, 16)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.70880075, -0.38527588, -0.41390185, ...,  0.98703104,
#          0.24154648, -0.45812285],
#        [ 1.70880075, -0.38527588, -0.41390185, ..., -0.59724808,
#         -1.39097457, -0.45812285],
#        [-0.58520574, -0.38527588,  2.41603173, ...,  0.72298452,
#          1.05780701, -0.45812285],
#        ...,
#        [-0.58520574, -0.38527588, -0.41390185, ..., -1.12534112,
#          0.24154648, -0.45812285],
#        [-0.58520574, -0.38527588, -0.41390185, ..., -1.12534112,
#          0.24154648, -0.45812285],
#        [ 1.70880075, -0.38527588, -0.41390185, ...,  3.36344971,
#          0.24154648,  2.18282063]])

# %%
y_train
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No'], dtype=object)

# %%
x_test
# Out:
# array([[-0.58520574, -0.38527588, -0.41390185, ..., -0.59724808,
#         -0.57471404, -0.45812285],
#        [-0.58520574,  2.59554274, -0.41390185, ..., -0.59724808,
#         -2.2072351 ,  2.18282063],
#        [-0.58520574,  2.59554274, -0.41390185, ...,  0.72298452,
#         -0.57471404, -0.45812285],
#        ...,
#        [-0.58520574, -0.38527588, -0.41390185, ..., -1.12534112,
#         -2.2072351 , -0.45812285],
#        [-0.58520574, -0.38527588, -0.41390185, ..., -0.59724808,
#         -0.57471404,  2.18282063],
#        [-0.58520574, -0.38527588, -0.41390185, ...,  1.25107756,
#          0.24154648, -0.45812285]])

# %%
y_test
# Out:
# array(['Yes', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_predict =lr.predict(x_test)

# %%
y_predict
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.8375850340136054

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[984,   3],
#        [188,   1]], dtype=int64)

# %%
import sklearn.metrics as metrics
fpr,tpr,threshold = metrics.roc_curve(y_test,y_predict)
roc_auc = metrics.auc(fpr,tpr)
roc_auc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-b1c02fcd85cc> in <module>
#       1 import sklearn.metrics as metrics
# ----> 2 fpr,tpr,threshold = metrics.roc_curve(y_test,y_predict)
#       3 roc_auc = metrics.auc(fpr,tpr)
#       4 roc_auc
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     616     """
#     617     fps, tps, thresholds = _binary_clf_curve(
# --> 618         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     619
#     620     # Attempt to drop thresholds corresponding to points in between and
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     414              np.array_equal(classes, [-1]) or
#     415              np.array_equal(classes, [1]))):
# --> 416         raise ValueError("Data is not binary and pos_label is not specified")
#     417     elif pos_label is None:
#     418         pos_label = 1.
#
# ValueError: Data is not binary and pos_label is not specified

# %%
plt.title('Employee Attrition')
plt.plot(fpr,tpr,label='AUC=%0.3f'%roc_auc,color='Blue')
plt.legend()
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-309651e6ed9d> in <module>
#       1 plt.title('Employee Attrition')
# ----> 2 plt.plot(fpr,tpr,label='AUC=%0.3f'%roc_auc,color='Blue')
#       3 plt.legend()
#       4 plt.plot()
#
# NameError: name 'fpr' is not defined
